# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904646-cmyk/btap/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Nhập một số: "))
s = 0
i = 0
while i < n:
  s = s + i
  i = i + 2
print(f"Tổng các số chẵn nhỏ hơn {n} là: {s}")
# Out:
# Nhập một số: 12
# Tổng các số chẵn nhỏ hơn 12 là: 30
