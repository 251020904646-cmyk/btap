# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904646-cmyk/btap/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Nhập số nguyên dương n: "))
t = 0
for i in range(n + 1):
    t += i
print(f"Tổng các số từ 0 đến {n} là: {t}")
# Out:
# Nhập số nguyên dương n: 4
# Tổng các số từ 0 đến 4 là: 10
